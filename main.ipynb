# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
inp = pd.read_csv("data.csv", sep=" ").to_numpy()

# %%
plt.plot(inp)

# %%
fr = np.fft.fft(inp)

# %%
plt.plot(fr)
# Out:
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# ...

# %%
fr
# Out:
# array([[ 61530.000488, -61529.999512],
#        [ 17580.000976, -17579.999024],
#        [-14899.998536,  14900.001464],
#        ...,
#        [ -9549.331   ,   9552.669   ],
#        [ -7040.331   ,   7043.669   ],
#        [ -5384.33    ,   5387.67    ]])
